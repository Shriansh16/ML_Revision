# %% [markdown]
# <a href="https://colab.research.google.com/github/Shriansh16/ML_Revision/blob/main/productivity_timeseries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/AssignmentData.xlsx - WorkerFunnel.csv')

# %%
df.head()
# Out:
#        Date Quarter Department  Targeted Productivity  Overtime  \
# 0  1/1/2015      Q1     Sewing                   0.80      7080
# 1  1/1/2015      Q1  Finishing                   0.75       960
# 2  1/1/2015      Q1     Sewing                   0.80      3660
# 3  1/1/2015      Q1     Sewing                   0.80      3660
# 4  1/1/2015      Q1     Sewing                   0.80      1920
#
#    No. of Workers  Actual Productivity
# 0            59.0             0.940725
# 1             8.0             0.886500
# 2            30.5             0.800570
# 3            30.5             0.800570
# 4            56.0                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   1197 non-null   object
#  1   Quarter                1197 non-null   object
#  2   Department             1197 non-null   object
#  3   Targeted Productivity  1197 non-null   float64
#  4   Overtime               1197 non-null   int64
#  5   No. of Workers         1197 non-null   float64
#  6   Actual Productivity    1197 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 65.6+ KB

# %% [markdown]
# #DATA CLEANING

# %%
df.shape
# Out:
# (1197, 7)

# %%
df.isnull().sum()
# Out:
# Date                      0
# Quarter                   0
# Department                0
# Targeted Productivity     0
# Overtime                  0
# No. of Workers            0
# Actual Productivity      30
# dtype: int64

# %% [markdown]
# ####HANDLING THE MISSING VALUES OF 'Actual Productivity'

# %%
df['Quarter'].value_counts()
# Out:
# Q1    360
# Q2    335
# Q4    248
# Q3    210
# Q5     44
# Name: Quarter, dtype: int64

# %% [markdown]
# HANDLING MISSING VALUES OF 'Actual Productivity' QUARTER WISE

# %% [markdown]
# ####QUARTER 1

# %%
df[df['Quarter']=='Q1'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      9
# dtype: int64

# %%
df[df['Quarter']=='Q1']['Actual Productivity'].median()
# Out:
# 0.800034503

# %% [markdown]
# filling the missing values of 'Actual Productivity' with the median of 'Actual Productivity' in Quarter 1

# %%
median1=df[df['Quarter']=='Q1']['Actual Productivity'].median()

# %%
median1
# Out:
# 0.800034503

# %%
df[df['Quarter']=='Q1']=df[df['Quarter']=='Q1'].fillna(median1)

# %%
df[df['Quarter']=='Q1']
# Out:
#           Date Quarter Department  Targeted Productivity  Overtime  \
# 0     1/1/2015      Q1     Sewing                   0.80      7080
# 1     1/1/2015      Q1  Finishing                   0.75       960
# 2     1/1/2015      Q1     Sewing                   0.80      3660
# 3     1/1/2015      Q1     Sewing                   0.80      3660
# 4     1/1/2015      Q1     Sewing                   0.80      1920
# ...        ...     ...        ...                    ...       ...
# 1101  7/3/2015      Q1     Sewing                   0.65      4200
# 1102  7/3/2015      Q1  Finishing                   0.80      3600
# 1103  7/3/2015      Q1  Finishing                   0.65      1920
# 1104  7/3/2015      Q1     Sewing                   0.50      2280
# 1105  7/3/2015      Q1     Sewing                   0.70      6960
#
#       No. of Workers  Actual Productivity
# 0               59.0             0.940725
# 1                8.0             0.886500
# ...

# %%
df[df['Quarter']=='Q1'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                      0
# Quarter                   0
# Department                0
# Targeted Productivity     0
# Overtime                  0
# No. of Workers            0
# Actual Productivity      21
# dtype: int64

# %% [markdown]
# ####QUARTER 2

# %%
df[df['Quarter']=='Q2'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      8
# dtype: int64

# %%
median2=df[df['Quarter']=='Q2']['Actual Productivity'].median()

# %%
median2
# Out:
# 0.800034503

# %% [markdown]
# filling the missing values of 'Actual Productivity' with the median of 'Actual Productivity' in Quarter 2

# %%
df[df['Quarter']=='Q2']=df[df['Quarter']=='Q2'].fillna(median2)

# %%
df[df['Quarter']=='Q2'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                      0
# Quarter                   0
# Department                0
# Targeted Productivity     0
# Overtime                  0
# No. of Workers            0
# Actual Productivity      13
# dtype: int64

# %% [markdown]
# ####QUARTER 3

# %%
df[df['Quarter']=='Q3'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      5
# dtype: int64

# %%
median3=df[df['Quarter']=='Q3']['Actual Productivity'].median()

# %%
median3
# Out:
# 0.72830303

# %% [markdown]
# filling the missing values of 'Actual Productivity' with the median of 'Actual Productivity' in Quarter 3

# %%
df[df['Quarter']=='Q3']=df[df['Quarter']=='Q3'].fillna(median3)

# %%
df[df['Quarter']=='Q3'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      8
# dtype: int64

# %% [markdown]
# ####QUARTER 4

# %%
df[df['Quarter']=='Q4'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      7
# dtype: int64

# %%
median4=df[df['Quarter']=='Q4']['Actual Productivity'].median()

# %%
median4
# Out:
# 0.750371895

# %% [markdown]
# filling the missing values of 'Actual Productivity' with the median of 'Actual Productivity' in Quarter 4

# %%
df[df['Quarter']=='Q4']=df[df['Quarter']=='Q4'].fillna(median4)

# %%
df[df['Quarter']=='Q4'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      1
# dtype: int64

# %% [markdown]
# ####QUARTER 5

# %%
df[df['Quarter']=='Q5'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      1
# dtype: int64

# %%
median5=df[df['Quarter']=='Q5']['Actual Productivity'].median()

# %%
median5
# Out:
# 0.877552083

# %% [markdown]
# filling the missing values of 'Actual Productivity' with the median of 'Actual Productivity' in Quarter 5

# %%
df[df['Quarter']=='Q5']=df[df['Quarter']=='Q5'].fillna(median5)

# %%
df[df['Quarter']=='Q5'].isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                     0
# Quarter                  0
# Department               0
# Targeted Productivity    0
# Overtime                 0
# No. of Workers           0
# Actual Productivity      0
# dtype: int64

# %% [markdown]
# ####All the missing values are handled

# %%
df.head()
# Out:
#        Date Quarter Department  Targeted Productivity  Overtime  \
# 0  1/1/2015      Q1     Sewing                   0.80      7080
# 1  1/1/2015      Q1  Finishing                   0.75       960
# 2  1/1/2015      Q1     Sewing                   0.80      3660
# 3  1/1/2015      Q1     Sewing                   0.80      3660
# 4  1/1/2015      Q1     Sewing                   0.80      1920
#
#    No. of Workers  Actual Productivity
# 0            59.0             0.940725
# 1             8.0             0.886500
# 2            30.5             0.800570
# 3            30.5             0.800570
# 4            56.0             0.800035

# %%
df
# Out:
#            Date Quarter Department  Targeted Productivity  Overtime  \
# 0      1/1/2015      Q1     Sewing                   0.80      7080
# 1      1/1/2015      Q1  Finishing                   0.75       960
# 2      1/1/2015      Q1     Sewing                   0.80      3660
# 3      1/1/2015      Q1     Sewing                   0.80      3660
# 4      1/1/2015      Q1     Sewing                   0.80      1920
# ...         ...     ...        ...                    ...       ...
# 1192  11/3/2015      Q2  Finishing                   0.75       960
# 1193  11/3/2015      Q2  Finishing                   0.70       960
# 1194  11/3/2015      Q2  Finishing                   0.65       960
# 1195  11/3/2015      Q2  Finishing                   0.75      1800
# 1196  11/3/2015      Q2  Finishing                   0.70       720
#
#       No. of Workers  Actual Productivity
# 0               59.0             0.940725
# 1                8.0             0.886500
# ...

# %%
df_sewing=df[df['Department']=='Sewing']
df_finishing=df[df['Department']=='Finishing']

# %%
df_sewing.reset_index(inplace=True,drop=True)

# %%
df_sewing.drop('index',axis=1,inplace=True)
# Out:
# <ipython-input-53-49dc963dd89f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sewing.drop('index',axis=1,inplace=True)

# %%
df_sewing
# Out:
#           Date Quarter Department  Targeted Productivity  Overtime  \
# 0     1/1/2015      Q1     Sewing                   0.80      7080
# 1     1/1/2015      Q1     Sewing                   0.80      3660
# 2     1/1/2015      Q1     Sewing                   0.80      3660
# 3     1/1/2015      Q1     Sewing                   0.80      1920
# 4     1/1/2015      Q1     Sewing                   0.80      6720
# ..         ...     ...        ...                    ...       ...
# 686  11/3/2015      Q2     Sewing                   0.75      7080
# 687  11/3/2015      Q2     Sewing                   0.70      6960
# 688  11/3/2015      Q2     Sewing                   0.70      6840
# 689  11/3/2015      Q2     Sewing                   0.70      4560
# 690  11/3/2015      Q2     Sewing                   0.65      6840
#
#      No. of Workers  Actual Productivity
# 0              59.0             0.940725
# 1              30.5             0.800570
# ...

# %%
df = df.groupby(['Date', 'Quarter', 'Department']).agg({
    'Targeted Productivity': 'mean',
    'Overtime': 'sum',
    'No. of Workers': 'sum',
    'Actual Productivity': 'mean'
}).reset_index()

# %%
df
# Out:
#           Date Quarter Department  Targeted Productivity  Overtime  \
# 0     1/1/2015      Q1  Finishing               0.735714      8400
# 1     1/1/2015      Q1     Sewing               0.762500     67080
# 2    1/13/2015      Q2  Finishing               0.740000     19260
# 3    1/13/2015      Q2     Sewing               0.720833    113760
# 4    1/14/2015      Q2  Finishing               0.740000     15840
# ..         ...     ...        ...                    ...       ...
# 113   8/3/2015      Q2     Sewing               0.704545     57420
# 114   9/2/2015      Q2  Finishing               0.716667      8160
# 115   9/2/2015      Q2     Sewing               0.700000     48840
# 116   9/3/2015      Q2  Finishing               0.730000         0
# 117   9/3/2015      Q2     Sewing               0.704167     69540
#
#      No. of Workers  Actual Productivity
# 0              70.0             0.708296
# 1             604.0             0.755066
# ...

# %%
df_sewing=df[df['Department']=='Sewing']

# %%
df_sewing
# Out:
#           Date Quarter Department  Targeted Productivity  Overtime  \
# 1     1/1/2015      Q1     Sewing               0.762500     67080
# 3    1/13/2015      Q2     Sewing               0.720833    113760
# 5    1/14/2015      Q2     Sewing               0.704545     77490
# 7    1/15/2015      Q3     Sewing               0.687500    110850
# 9    1/17/2015      Q3     Sewing               0.720833    109890
# 11   1/18/2015      Q3     Sewing               0.729167    106800
# 13   1/19/2015      Q3     Sewing               0.683333    104400
# 15    1/2/2015      Q1     Sewing               0.740909     62340
# 17   1/20/2015      Q3     Sewing               0.677273     99750
# 19   1/21/2015      Q3     Sewing               0.700000    105690
# 21   1/22/2015      Q4     Sewing               0.691667    118710
# 23   1/24/2015      Q4     Sewing               0.691667    109770
# 25   1/25/2015      Q4     Sewing               0.708333    105660
# ...
